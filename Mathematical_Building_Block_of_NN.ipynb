# %% [markdown]
# <a href="https://colab.research.google.com/github/NayeemHossenJim/Hands-on-Machine-Learning-Book-Study/blob/main/Mathematical_Building_Block_of_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')
  ])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_train = X_train.astype('float32') / 255
X_test = X_test.reshape((10000, 28 * 28))
X_test = X_test.astype('float32') / 255

# %%
model.fit(X_train, y_train, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8713 - loss: 0.4655
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9645 - loss: 0.1237
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9789 - loss: 0.0715
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9850 - loss: 0.0497
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9898 - loss: 0.0355

# %%
test_digits = X_test[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# array([9.4528204e-08, 1.3727321e-08, 4.5731126e-06, 8.2347404e-05,
#        4.0727280e-10, 8.5741043e-08, 1.3826364e-11, 9.9990106e-01,
#        9.3452445e-07, 1.0836523e-05], dtype=float32)

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9781 - loss: 0.0734
# [0.06376006454229355, 0.9811999797821045]
